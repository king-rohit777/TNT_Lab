# %% [markdown]
# **IMPLEMENT THE FOLLOWING SORTING ALGORITHMS :**
#
# - SELECTION SORT
# - INSERTION SORT
# - BUBBLE SORT
# - QUICK SORT
# - MERGE SORT

# %%
n= int(input("Enter the number of elements: "))
arr=[]
for i in range(n):
    l=int(input())
    arr.append(l)

print ("The unsorted array is: ",arr)

def selection_sort(arr):
    for i in range(len (arr)):
        min_idx=i
        for j in range(i+1,len(arr)):
            if arr[min_idx] > arr[j]:
                min_idx=j
        arr[i],arr[min_idx]=arr[min_idx],arr[i]
    return(arr)

def insertion_sort(arr):
    for i in range(1, len(arr)):
        key = arr[i]
        j = i - 1
 
        while j >= 0 and key < arr[j]:
            arr[j + 1] = arr[j]
            j = j - 1
        arr[j + 1] = key
    return (arr)

def bubble_sort(arr):
    for i in range(len(arr)):
        for j in range(0, len(arr) - i - 1):
            if arr[j] > arr[j + 1]:
                temp = arr[j]
                arr[j] = arr[j+1]
                arr[j+1] = temp
    
    return (arr)
        
# Quick Sort Partition
def partition(arr, low, high):
  
  pivot = arr[high]
  i = low - 1

  for j in range(low, high):
    if arr[j] <= pivot:
      i = i + 1
      (arr[i], arr[j]) = (arr[j], arr[i])


  (arr[i + 1], arr[high]) = (arr[high], arr[i + 1])
  return i + 1
        

def quickSort(arr, low, high):
  if low < high:

    pi = partition(arr, low, high)
    quickSort(arr, low, pi - 1)
    quickSort(arr, pi + 1, high)

size=len(arr)
quickSort(arr,0,size-1)

#Merge Sort

def mergeSort(arr):
    if len(arr) > 1:

        r = len(arr)//2
        L = arr[:r]
        M = arr[r:]

        
        mergeSort(L)
        mergeSort(M)

        i = j = k = 0

        while i < len(L) and j < len(M):
            if L[i] < M[j]:
                arr[k] = L[i]
                i += 1
            else:
                arr[k] = M[j]
                j += 1
            k += 1

        while i < len(L):
            arr[k] = L[i]
            i += 1
            k += 1

        while j < len(M):
            arr[k] = M[j]
            j += 1
            k += 1

print ("The sorted array after Merge Sort: ",arr)    
print ("The sorted array after QuickSort: ",arr)    
print("sorted Array after selection sort: ",selection_sort(arr))
print("sorted Array after Insertion sort: ",insertion_sort(arr))
print("sorted Array after Bubble sort: ",bubble_sort(arr))
# Out:
# The unsorted array is:  [5, 4, 3, 2, 1]
# The sorted array after Merge Sort:  [1, 2, 3, 4, 5]
# The sorted array after QuickSort:  [1, 2, 3, 4, 5]
# sorted Array after selection sort:  [1, 2, 3, 4, 5]
# sorted Array after Insertion sort:  [1, 2, 3, 4, 5]
# sorted Array after Bubble sort:  [1, 2, 3, 4, 5]
