# %%
# !pip install xgboost -q

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer

import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
df = pd.read_excel('Vehicle_01.xlsx')
df
# Out:
#      Compactness   Circularity   Distance_circularity   Radius_ratio  \
# 0             85            45                     80            154
# 1             93            35                     78            162
# 2            108            49                    109            204
# 3             93            40                     73            139
# 4            100            58                    109            230
# ..           ...           ...                    ...            ...
# 841           80            43                     71            133
# 842          104            50                    106            209
# 843          109            49                    103            186
# 844           90            40                     83            178
# 845           89            47                     84            133
#
#       Praxis_aspect_ratio   Max_length_aspect_ratio   Scatter_ratio  \
# 0                      64                         9             147
# 1                      60                         8             150
# 2                      61                        11             212
# 3                      58                         6             136
# 4                      70                        11             226
# ..                    ...                       ...             ...
# 841                    60                         7             150
# 842                    66                        10             207
# 843                    57                        11             206
# 844                    61                         8             178
# 845                    55                        11             157
#
#       Elongatedness   Praxis_rectangular   Length_rectangular  \
# 0                45                   19                  148
# 1                45                   19                  125
# 2                31                   24                  159
# 3                49                   18                  138
# 4                30                   25                  182
# ..              ...                  ...                  ...
# 841              45                   19                  146
# 842              32                   23                  158
# 843              32                   23                  156
# 844              37                   21                  132
# 845              44                   20                  160
#
#       Major_variance   Minor_variance   Gyration_radius   Major_skewness  \
# 0                169              324               174               71
# 1                172              331               137               67
# 2                229              665               215               71
# 3                166              275               137               73
# 4                234              752               207               72
# ..               ...              ...               ...              ...
# 841              170              330               176               81
# 842              223              635               220               73
# 843              212              630               186               65
# 844              199              472               157               71
# 845              169              354               176               74
#
#       Minor_skewness   Minor_kurtosis   Major_kurtosis   Hollows_ratio  \
# 0                  1                4              188             199
# 1                  2               33              191             198
# 2                 16               11              190             199
# 3                  0                0              187             188
# 4                  0               13              187             198
# ..               ...              ...              ...             ...
# 841                6               15              180             184
# 842               14                9              188             196
# 843               12               21              192             201
# 844                1               14              187             193
# 845                5                9              182             192
#
#          Class
# 0     positive
# 1     negative
# 2     negative
# 3     positive
# 4     negative
# ..         ...
# 841   negative
# 842   negative
# 843   negative
# 844   negative
# 845   positive
#
# [846 rows x 19 columns]

# %% [markdown]
# # EDA

# %%
df.dtypes
# Out:
# Compactness                  int64
#  Circularity                 int64
#  Distance_circularity        int64
#  Radius_ratio                int64
#  Praxis_aspect_ratio         int64
#  Max_length_aspect_ratio     int64
#  Scatter_ratio               int64
#  Elongatedness               int64
#  Praxis_rectangular          int64
#  Length_rectangular          int64
#  Major_variance              int64
#  Minor_variance              int64
#  Gyration_radius             int64
#  Major_skewness              int64
#  Minor_skewness              int64
#  Minor_kurtosis              int64
#  Major_kurtosis              int64
#  Hollows_ratio               int64
# Class                       object
# dtype: object

# %%
df.isna().sum()
# Out:
# Compactness                 0
#  Circularity                0
#  Distance_circularity       0
#  Radius_ratio               0
#  Praxis_aspect_ratio        0
#  Max_length_aspect_ratio    0
#  Scatter_ratio              0
#  Elongatedness              0
#  Praxis_rectangular         0
#  Length_rectangular         0
#  Major_variance             0
#  Minor_variance             0
#  Gyration_radius            0
#  Major_skewness             0
#  Minor_skewness             0
#  Minor_kurtosis             0
#  Major_kurtosis             0
#  Hollows_ratio              0
# Class                       0
# dtype: int64

# %%
df.shape
# Out:
# (846, 19)

# %%
df.head()
# Out:
#    Compactness   Circularity   Distance_circularity   Radius_ratio  \
# 0           85            45                     80            154
# 1           93            35                     78            162
# 2          108            49                    109            204
# 3           93            40                     73            139
# 4          100            58                    109            230
#
#     Praxis_aspect_ratio   Max_length_aspect_ratio   Scatter_ratio  \
# 0                    64                         9             147
# 1                    60                         8             150
# 2                    61                        11             212
# 3                    58                         6             136
# 4                    70                        11             226
#
#     Elongatedness   Praxis_rectangular   Length_rectangular   Major_variance  \
# 0              45                   19                  148              169
# 1              45                   19                  125              172
# 2              31                   24                  159              229
# 3              49                   18                  138              166
# 4              30                   25                  182              234
#
#     Minor_variance   Gyration_radius   Major_skewness   Minor_skewness  \
# 0              324               174               71                1
# 1              331               137               67                2
# 2              665               215               71               16
# 3              275               137               73                0
# 4              752               207               72                0
#
#     Minor_kurtosis   Major_kurtosis   Hollows_ratio      Class
# 0                4              188             199   positive
# 1               33              191             198   negative
# 2               11              190             199   negative
# 3                0              187             188   positive
# 4               13              187             198   negative

# %%
df.hist(figsize=(12,12))
plt.show()

# %%
df.describe()
# Out:
#        Compactness   Circularity   Distance_circularity   Radius_ratio  \
# count   846.000000    846.000000             846.000000     846.000000
# mean     93.678487     44.861702              82.088652     168.940898
# std       8.234474      6.169866              15.771533      33.472183
# min      73.000000     33.000000              40.000000     104.000000
# 25%      87.000000     40.000000              70.000000     141.000000
# 50%      93.000000     44.000000              80.000000     167.000000
# 75%     100.000000     49.000000              98.000000     195.000000
# max     119.000000     59.000000             112.000000     333.000000
#
#         Praxis_aspect_ratio   Max_length_aspect_ratio   Scatter_ratio  \
# count            846.000000                846.000000      846.000000
# mean              61.693853                  8.567376      168.839243
# std                7.888251                  4.601217       33.244978
# min               47.000000                  2.000000      112.000000
# 25%               57.000000                  7.000000      146.250000
# 50%               61.000000                  8.000000      157.000000
# 75%               65.000000                 10.000000      198.000000
# max              138.000000                 55.000000      265.000000
#
#         Elongatedness   Praxis_rectangular   Length_rectangular  \
# count      846.000000           846.000000           846.000000
# mean        40.933806            20.582742           147.998818
# std          7.811560             2.592138            14.515652
# min         26.000000            17.000000           118.000000
# 25%         33.000000            19.000000           137.000000
# 50%         43.000000            20.000000           146.000000
# 75%         46.000000            23.000000           159.000000
# max         61.000000            29.000000           188.000000
#
#         Major_variance   Minor_variance   Gyration_radius   Major_skewness  \
# count       846.000000       846.000000         846.00000       846.000000
# mean        188.625296       439.911348         174.70331        72.462175
# std          31.394837       176.692614          32.54649         7.486974
# min         130.000000       184.000000         109.00000        59.000000
# 25%         167.000000       318.250000         149.00000        67.000000
# 50%         178.500000       364.000000         173.00000        71.500000
# 75%         217.000000       587.000000         198.00000        75.000000
# max         320.000000      1018.000000         268.00000       135.000000
#
#         Minor_skewness   Minor_kurtosis   Major_kurtosis   Hollows_ratio
# count       846.000000       846.000000       846.000000      846.000000
# mean          6.377069        12.599291       188.932624      195.632388
# std           4.918353         8.931240         6.163949        7.438797
# min           0.000000         0.000000       176.000000      181.000000
# 25%           2.000000         5.000000       184.000000      190.250000
# 50%           6.000000        11.000000       188.000000      197.000000
# 75%           9.000000        19.000000       193.000000      201.000000
# max          22.000000        41.000000       206.000000      211.000000

# %%
df.describe(include='object')
# Out:
#             Class
# count         846
# unique          2
# top      negative
# freq          647

# %%
corr = df.corr()
corr
# Out:
#                           Compactness   Circularity   Distance_circularity  \
# Compactness                  1.000000      0.692869               0.792444
#  Circularity                 0.692869      1.000000               0.798492
#  Distance_circularity        0.792444      0.798492               1.000000
#  Radius_ratio                0.691659      0.622778               0.771644
#  Praxis_aspect_ratio         0.093222      0.149692               0.161529
#  Max_length_aspect_ratio     0.148249      0.247467               0.264309
#  Scatter_ratio               0.813003      0.860367               0.907280
#  Elongatedness              -0.788647     -0.828755              -0.912307
#  Praxis_rectangular          0.813437      0.857925               0.895326
#  Length_rectangular          0.676143      0.965776               0.774524
#  Major_variance              0.764415      0.808496               0.864432
#  Minor_variance              0.818632      0.852679               0.889661
#  Gyration_radius             0.585347      0.936080               0.705818
#  Major_skewness             -0.252984      0.058669              -0.231660
#  Minor_skewness              0.233693      0.148433               0.116478
#  Minor_kurtosis              0.156779     -0.015482               0.264522
#  Major_kurtosis              0.297780     -0.113047               0.147980
#  Hollows_ratio               0.365552      0.038677               0.335453
#
#                            Radius_ratio   Praxis_aspect_ratio  \
# Compactness                    0.691659              0.093222
#  Circularity                   0.622778              0.149692
#  Distance_circularity          0.771644              0.161529
#  Radius_ratio                  1.000000              0.665407
#  Praxis_aspect_ratio           0.665407              1.000000
#  Max_length_aspect_ratio       0.448048              0.648096
#  Scatter_ratio                 0.738460              0.106064
#  Elongatedness                -0.792557             -0.185086
#  Praxis_rectangular            0.711497              0.079982
#  Length_rectangular            0.570154              0.129168
#  Major_variance                0.797588              0.274705
#  Minor_variance                0.725781              0.092182
#  Gyration_radius               0.539069              0.124408
#  Major_skewness               -0.182412              0.152304
#  Minor_skewness                0.050534             -0.056807
#  Minor_kurtosis                0.174299             -0.034180
#  Major_kurtosis                0.380757              0.238195
#  Hollows_ratio                 0.469278              0.267381
#
#                            Max_length_aspect_ratio   Scatter_ratio  \
# Compactness                               0.148249        0.813003
#  Circularity                              0.247467        0.860367
#  Distance_circularity                     0.264309        0.907280
#  Radius_ratio                             0.448048        0.738460
#  Praxis_aspect_ratio                      0.648096        0.106064
#  Max_length_aspect_ratio                  1.000000        0.166769
#  Scatter_ratio                            0.166769        1.000000
#  Elongatedness                           -0.180044       -0.973385
#  Praxis_rectangular                       0.161861        0.992088
#  Length_rectangular                       0.305943        0.810648
#  Major_variance                           0.319430        0.951862
#  Minor_variance                           0.144606        0.996318
#  Gyration_radius                          0.189791        0.800932
#  Major_skewness                           0.294548       -0.028618
#  Minor_skewness                           0.015218        0.074347
#  Minor_kurtosis                           0.043379        0.210706
#  Major_kurtosis                          -0.027317        0.004053
#  Hollows_ratio                            0.143919        0.119950
#
#                            Elongatedness   Praxis_rectangular  \
# Compactness                    -0.788647             0.813437
#  Circularity                   -0.828755             0.857925
#  Distance_circularity          -0.912307             0.895326
#  Radius_ratio                  -0.792557             0.711497
#  Praxis_aspect_ratio           -0.185086             0.079982
#  Max_length_aspect_ratio       -0.180044             0.161861
#  Scatter_ratio                 -0.973385             0.992088
#  Elongatedness                  1.000000            -0.950512
#  Praxis_rectangular            -0.950512             1.000000
#  Length_rectangular            -0.775531             0.813305
#  Major_variance                -0.938392             0.938266
#  Minor_variance                -0.956522             0.992346
#  Gyration_radius               -0.766146             0.798282
#  Major_skewness                 0.104875            -0.016333
#  Minor_skewness                -0.053346             0.082346
#  Minor_kurtosis                -0.185189             0.213088
#  Major_kurtosis                -0.112046            -0.022056
#  Hollows_ratio                 -0.216725             0.098519
#
#                            Length_rectangular   Major_variance  \
# Compactness                          0.676143         0.764415
#  Circularity                         0.965776         0.808496
#  Distance_circularity                0.774524         0.864432
#  Radius_ratio                        0.570154         0.797588
#  Praxis_aspect_ratio                 0.129168         0.274705
#  Max_length_aspect_ratio             0.305943         0.319430
#  Scatter_ratio                       0.810648         0.951862
#  Elongatedness                      -0.775531        -0.938392
#  Praxis_rectangular                  0.813305         0.938266
#  Length_rectangular                  1.000000         0.747152
#  Major_variance                      0.747152         1.000000
#  Minor_variance                      0.798071         0.949888
#  Gyration_radius                     0.866479         0.780962
#  Major_skewness                      0.040339         0.111296
#  Minor_skewness                      0.137473         0.039137
#  Minor_kurtosis                      0.001183         0.191948
#  Major_kurtosis                     -0.107718         0.011189
#  Hollows_ratio                       0.076770         0.085540
#
#                            Minor_variance   Gyration_radius   Major_skewness  \
# Compactness                      0.818632          0.585347        -0.252984
#  Circularity                     0.852679          0.936080         0.058669
#  Distance_circularity            0.889661          0.705818        -0.231660
#  Radius_ratio                    0.725781          0.539069        -0.182412
#  Praxis_aspect_ratio             0.092182          0.124408         0.152304
#  Max_length_aspect_ratio         0.144606          0.189791         0.294548
#  Scatter_ratio                   0.996318          0.800932        -0.028618
#  Elongatedness                  -0.956522         -0.766146         0.104875
#  Praxis_rectangular              0.992346          0.798282        -0.016333
#  Length_rectangular              0.798071          0.866479         0.040339
#  Major_variance                  0.949888          0.780962         0.111296
#  Minor_variance                  1.000000          0.797540        -0.019872
#  Gyration_radius                 0.797540          1.000000         0.191209
#  Major_skewness                 -0.019872          0.191209         1.000000
#  Minor_skewness                  0.076435          0.168003        -0.092539
#  Minor_kurtosis                  0.202894         -0.056218        -0.126157
#  Major_kurtosis                  0.005380         -0.227366        -0.754142
#  Hollows_ratio                   0.105432         -0.117808        -0.805399
#
#                            Minor_skewness   Minor_kurtosis   Major_kurtosis  \
# Compactness                      0.233693         0.156779         0.297780
#  Circularity                     0.148433        -0.015482        -0.113047
#  Distance_circularity            0.116478         0.264522         0.147980
#  Radius_ratio                    0.050534         0.174299         0.380757
#  Praxis_aspect_ratio            -0.056807        -0.034180         0.238195
#  Max_length_aspect_ratio         0.015218         0.043379        -0.027317
#  Scatter_ratio                   0.074347         0.210706         0.004053
#  Elongatedness                  -0.053346        -0.185189        -0.112046
#  Praxis_rectangular              0.082346         0.213088        -0.022056
#  Length_rectangular              0.137473         0.001183        -0.107718
#  Major_variance                  0.039137         0.191948         0.011189
#  Minor_variance                  0.076435         0.202894         0.005380
#  Gyration_radius                 0.168003        -0.056218        -0.227366
#  Major_skewness                 -0.092539        -0.126157        -0.754142
#  Minor_skewness                  1.000000        -0.039365         0.116932
#  Minor_kurtosis                 -0.039365         1.000000         0.079090
#  Major_kurtosis                  0.116932         0.079090         1.000000
#  Hollows_ratio                   0.099149         0.204924         0.894098
#
#                            Hollows_ratio
# Compactness                     0.365552
#  Circularity                    0.038677
#  Distance_circularity           0.335453
#  Radius_ratio                   0.469278
#  Praxis_aspect_ratio            0.267381
#  Max_length_aspect_ratio        0.143919
#  Scatter_ratio                  0.119950
#  Elongatedness                 -0.216725
#  Praxis_rectangular             0.098519
#  Length_rectangular             0.076770
#  Major_variance                 0.085540
#  Minor_variance                 0.105432
#  Gyration_radius               -0.117808
#  Major_skewness                -0.805399
#  Minor_skewness                 0.099149
#  Minor_kurtosis                 0.204924
#  Major_kurtosis                 0.894098
#  Hollows_ratio                  1.000000

# %%
plt.figure(figsize=(12,12))
sns.heatmap(corr, cmap='RdBu_r', annot=True, vmax=1, vmin=-1)
plt.show()

# %%
X = df.drop("Class", axis=1)
y = df.Class

# %%
numeric_pipeline = Pipeline(
    steps=[("impute", SimpleImputer(strategy="mean")), 
           ("scale", StandardScaler())]
)

# %%
num_cols = X.select_dtypes(include="number").columns

# %%
full_processor = ColumnTransformer(
    transformers=[
        ("numeric", numeric_pipeline, num_cols),
    ]
)

# %%
xgb_cl = xgb.XGBClassifier()

# %%
X_processed = full_processor.fit_transform(X)
y_processed = SimpleImputer(strategy="most_frequent").fit_transform(
    y.values.reshape(-1, 1)
)


X_train, X_test, y_train, y_test = train_test_split(
    X_processed, y_processed, stratify=y_processed, random_state=42
)

# %%
xgb_cl = xgb.XGBClassifier()

xgb_cl.fit(X_train, y_train)

preds = xgb_cl.predict(X_test)
# Out:
# [11:53:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# C:\Users\KIIT\AppData\Roaming\Python\Python39\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# C:\Users\KIIT\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
accuracy_score(y_test, preds)*100
# Out:
# 96.22641509433963
